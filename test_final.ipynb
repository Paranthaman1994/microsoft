# %%
import pandas as pd

# %% [markdown]
# Read the Data

# %%
df=pd.read_csv("GUIDE_Test.csv", nrows=10000, low_memory=False)

# %%
df
# Out:
#                  Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0     1245540519230    657       11767    87199  2024-06-04T22:56:27.000Z
# 1     1400159342154      3       91158   632273  2024-06-03T12:58:26.000Z
# 2     1279900255923    145       32247   131719  2024-06-08T03:20:49.000Z
# 3       60129547292    222       15294   917686  2024-06-12T12:07:31.000Z
# 4      515396080539    363        7615     5944  2024-06-06T17:42:05.000Z
# ...             ...    ...         ...      ...                       ...
# 9995   738734375582     22         933   547212  2024-06-05T12:49:29.000Z
# 9996  1511828492479     36       92513    66367  2024-06-09T20:04:20.000Z
# 9997  1279900256743      5         172   373507  2024-06-03T06:10:43.000Z
# 9998  1597727835731      1         273   402248  2024-06-11T13:57:52.000Z
# 9999   893353202427      4         398      421  2024-05-20T09:02:09.000Z
#
#       DetectorId  AlertTitle           Category  \
# 0            524         563    LateralMovement
# 1              2           2  CommandAndControl
# 2           2932       10807    LateralMovement
# 3              0           0      InitialAccess
# 4             27          18          Discovery
# ...          ...         ...                ...
# 9995           0           0      InitialAccess
# 9996           1           1      InitialAccess
# 9997           0           0      InitialAccess
# 9998           0           0      InitialAccess
# 9999           8           7      InitialAccess
#
#                       MitreTechniques   IncidentGrade  ...       Roles  \
# 0         T1021;T1047;T1105;T1569.002  BenignPositive  ...         NaN
# 1                                 NaN  BenignPositive  ...         NaN
# 2     T1021;T1027.002;T1027.005;T1105  BenignPositive  ...         NaN
# 3                     T1078;T1078.004   FalsePositive  ...         NaN
# 4                     T1087;T1087.002  BenignPositive  ...  Suspicious
# ...                               ...             ...  ...         ...
# 9995                  T1078;T1078.004    TruePositive  ...         NaN
# 9996                        T1566.002  BenignPositive  ...         NaN
# 9997                  T1078;T1078.004    TruePositive  ...         NaN
# 9998                  T1078;T1078.004    TruePositive  ...         NaN
# 9999                            T1133   FalsePositive  ...         NaN
#
#      OSFamily OSVersion AntispamDirection  SuspicionLevel  LastVerdict  \
# 0           5        66               NaN      Suspicious   Suspicious
# 1           0         0               NaN      Suspicious   Suspicious
# 2           5        66               NaN      Suspicious   Suspicious
# 3           5        66               NaN             NaN          NaN
# 4           5        66               NaN             NaN          NaN
# ...       ...       ...               ...             ...          ...
# 9995        5        66               NaN             NaN          NaN
# 9996        5        66               NaN             NaN    Malicious
# 9997        5        66               NaN             NaN          NaN
# 9998        5        66               NaN             NaN          NaN
# 9999        5        66               NaN             NaN          NaN
#
#       CountryCode  State   City    Usage
# 0             242   1445  10630  Private
# 1             242   1445  10630   Public
# 2             242   1445  10630   Public
# 3             242   1445  10630   Public
# 4             242   1445  10630   Public
# ...           ...    ...    ...      ...
# 9995          242   1445  10630   Public
# 9996          242   1445  10630  Private
# 9997           18     91    125   Public
# 9998            0     11      8  Private
# 9999          242   1445  10630   Public
#
# [10000 rows x 46 columns]

# %%
df.head(5)
# Out:
#               Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0  1245540519230    657       11767    87199  2024-06-04T22:56:27.000Z
# 1  1400159342154      3       91158   632273  2024-06-03T12:58:26.000Z
# 2  1279900255923    145       32247   131719  2024-06-08T03:20:49.000Z
# 3    60129547292    222       15294   917686  2024-06-12T12:07:31.000Z
# 4   515396080539    363        7615     5944  2024-06-06T17:42:05.000Z
#
#    DetectorId  AlertTitle           Category                  MitreTechniques  \
# 0         524         563    LateralMovement      T1021;T1047;T1105;T1569.002
# 1           2           2  CommandAndControl                              NaN
# 2        2932       10807    LateralMovement  T1021;T1027.002;T1027.005;T1105
# 3           0           0      InitialAccess                  T1078;T1078.004
# 4          27          18          Discovery                  T1087;T1087.002
#
#     IncidentGrade  ...       Roles OSFamily OSVersion AntispamDirection  \
# 0  BenignPositive  ...         NaN        5        66               NaN
# 1  BenignPositive  ...         NaN        0         0               NaN
# 2  BenignPositive  ...         NaN        5        66               NaN
# 3   FalsePositive  ...         NaN        5        66               NaN
# 4  BenignPositive  ...  Suspicious        5        66               NaN
#
#    SuspicionLevel  LastVerdict  CountryCode  State   City    Usage
# 0      Suspicious   Suspicious          242   1445  10630  Private
# 1      Suspicious   Suspicious          242   1445  10630   Public
# 2      Suspicious   Suspicious          242   1445  10630   Public
# 3             NaN          NaN          242   1445  10630   Public
# 4             NaN          NaN          242   1445  10630   Public
#
# [5 rows x 46 columns]

# %% [markdown]
# Drop the column

# %%
df=df.drop(columns="Usage")

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 45 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  10000 non-null  int64
#  1   orgid               10000 non-null  int64
#  2   incidentid          10000 non-null  int64
#  3   alertid             10000 non-null  int64
#  4   timestamp           10000 non-null  object
#  5   detectorid          10000 non-null  int64
#  6   alerttitle          10000 non-null  int64
#  7   category            10000 non-null  object
#  8   mitretechniques     4465 non-null   object
#  9   incidentgrade       10000 non-null  object
#  10  actiongrouped       4 non-null      object
#  11  actiongranular      4 non-null      object
#  12  entitytype          10000 non-null  object
#  13  evidencerole        10000 non-null  object
#  14  deviceid            10000 non-null  int64
#  15  sha256              10000 non-null  int64
#  16  ipaddress           10000 non-null  int64
#  17  url                 10000 non-null  int64
#  18  accountsid          10000 non-null  int64
#  19  accountupn          10000 non-null  int64
#  20  accountobjectid     10000 non-null  int64
#  21  accountname         10000 non-null  int64
#  22  devicename          10000 non-null  int64
#  23  networkmessageid    10000 non-null  int64
#  24  emailclusterid      95 non-null     float64
#  25  registrykey         10000 non-null  int64
#  26  registryvaluename   10000 non-null  int64
#  27  registryvaluedata   10000 non-null  int64
#  28  applicationid       10000 non-null  int64
#  29  applicationname     10000 non-null  int64
#  30  oauthapplicationid  10000 non-null  int64
#  31  threatfamily        72 non-null     object
#  32  filename            10000 non-null  int64
#  33  folderpath          10000 non-null  int64
#  34  resourceidname      10000 non-null  int64
#  35  resourcetype        8 non-null      object
#  36  roles               251 non-null    object
#  37  osfamily            10000 non-null  int64
#  38  osversion           10000 non-null  int64
#  39  antispamdirection   199 non-null    object
#  40  suspicionlevel      1546 non-null   object
#  41  lastverdict         2391 non-null   object
#  42  countrycode         10000 non-null  int64
#  43  state               10000 non-null  int64
#  44  city                10000 non-null  int64
# dtypes: float64(1), int64(30), object(14)
# memory usage: 3.4+ MB

# %%
df['timestamp']=pd.to_datetime(df['timestamp'])
df['hour']=df['timestamp'].dt.hour
df['day']=df['timestamp'].dt.day
df['month']=df['timestamp'].dt.month
df['year']=df['timestamp'].dt.year

# %%
df
# Out:
#                  id  orgid  incidentid  alertid                 timestamp  \
# 0     1245540519230    657       11767    87199 2024-06-04 22:56:27+00:00
# 1     1400159342154      3       91158   632273 2024-06-03 12:58:26+00:00
# 2     1279900255923    145       32247   131719 2024-06-08 03:20:49+00:00
# 3       60129547292    222       15294   917686 2024-06-12 12:07:31+00:00
# 4      515396080539    363        7615     5944 2024-06-06 17:42:05+00:00
# ...             ...    ...         ...      ...                       ...
# 9995   738734375582     22         933   547212 2024-06-05 12:49:29+00:00
# 9996  1511828492479     36       92513    66367 2024-06-09 20:04:20+00:00
# 9997  1279900256743      5         172   373507 2024-06-03 06:10:43+00:00
# 9998  1597727835731      1         273   402248 2024-06-11 13:57:52+00:00
# 9999   893353202427      4         398      421 2024-05-20 09:02:09+00:00
#
#       detectorid  alerttitle           category  \
# 0            524         563    LateralMovement
# 1              2           2  CommandAndControl
# 2           2932       10807    LateralMovement
# 3              0           0      InitialAccess
# 4             27          18          Discovery
# ...          ...         ...                ...
# 9995           0           0      InitialAccess
# 9996           1           1      InitialAccess
# 9997           0           0      InitialAccess
# 9998           0           0      InitialAccess
# 9999           8           7      InitialAccess
#
#                       mitretechniques   incidentgrade actiongrouped  \
# 0         T1021;T1047;T1105;T1569.002  BenignPositive           NaN
# 1                                 NaN  BenignPositive           NaN
# 2     T1021;T1027.002;T1027.005;T1105  BenignPositive           NaN
# 3                     T1078;T1078.004   FalsePositive           NaN
# 4                     T1087;T1087.002  BenignPositive           NaN
# ...                               ...             ...           ...
# 9995                  T1078;T1078.004    TruePositive           NaN
# 9996                        T1566.002  BenignPositive           NaN
# 9997                  T1078;T1078.004    TruePositive           NaN
# 9998                  T1078;T1078.004    TruePositive           NaN
# 9999                            T1133   FalsePositive           NaN
#
#      actiongranular         entitytype evidencerole  deviceid  sha256  \
# 0               NaN               User     Impacted     98799  138268
# 1               NaN            Machine     Impacted      1239  138268
# 2               NaN            Process      Related     98799    4296
# 3               NaN  CloudLogonSession      Related     98799  138268
# 4               NaN               User     Impacted     98799  138268
# ...             ...                ...          ...       ...     ...
# 9995            NaN  CloudLogonRequest      Related     98799  138268
# 9996            NaN        MailCluster      Related     98799  138268
# 9997            NaN                 Ip      Related     98799  138268
# 9998            NaN                 Ip      Related     98799  138268
# 9999            NaN            Machine     Impacted     98799  138268
#
#       ipaddress     url  accountsid  accountupn  accountobjectid  accountname  \
# 0        360606  160396        2610        3699           425863          863
# 1        360606  160396      441377      673934           425863       453297
# 2        360606  160396      441377      673934           425863       453297
# 3        360606  160396      441377      673934           425863       453297
# 4        360606  160396      133549      673934           425863       136104
# ...         ...     ...         ...         ...              ...          ...
# 9995     360606  160396      441377      673934           425863       453297
# 9996     360606  160396      441377      673934           425863       453297
# 9997      20463  160396      441377      673934           425863       453297
# 9998      16281  160396      441377      673934           425863       453297
# 9999     360606  160396      441377      673934           425863       453297
#
#       devicename  networkmessageid  emailclusterid  registrykey  \
# 0         153085            529644             NaN         1631
# 1           2833            529644             NaN         1631
# 2         153085            529644             NaN         1631
# 3         153085            529644             NaN         1631
# 4         153085            529644             NaN         1631
# ...          ...               ...             ...          ...
# 9995      153085            529644             NaN         1631
# 9996      153085            529644             NaN         1631
# 9997      153085            529644             NaN         1631
# 9998      153085            529644             NaN         1631
# 9999         216            529644             NaN         1631
#
#       registryvaluename  registryvaluedata  applicationid  applicationname  \
# 0                   635                860           2251             3421
# 1                   635                860           2251             3421
# 2                   635                860           2251             3421
# 3                   635                860           2251             3421
# 4                   635                860           2251             3421
# ...                 ...                ...            ...              ...
# 9995                635                860           2251             3421
# 9996                635                860           2251             3421
# 9997                635                860           2251             3421
# 9998                635                860           2251             3421
# 9999                635                860           2251             3421
#
#       oauthapplicationid threatfamily  filename  folderpath  resourceidname  \
# 0                    881          NaN    289573      117668            3586
# 1                    881          NaN    289573      117668            3586
# 2                    881          NaN        14          22            3586
# 3                    881          NaN    289573      117668            3586
# 4                    881          NaN    289573      117668            3586
# ...                  ...          ...       ...         ...             ...
# 9995                 881          NaN    289573      117668            3586
# 9996                 881          NaN    289573      117668            3586
# 9997                 881          NaN    289573      117668            3586
# 9998                 881          NaN    289573      117668            3586
# 9999                 881          NaN    289573      117668            3586
#
#      resourcetype       roles  osfamily  osversion antispamdirection  \
# 0             NaN         NaN         5         66               NaN
# 1             NaN         NaN         0          0               NaN
# 2             NaN         NaN         5         66               NaN
# 3             NaN         NaN         5         66               NaN
# 4             NaN  Suspicious         5         66               NaN
# ...           ...         ...       ...        ...               ...
# 9995          NaN         NaN         5         66               NaN
# 9996          NaN         NaN         5         66               NaN
# 9997          NaN         NaN         5         66               NaN
# 9998          NaN         NaN         5         66               NaN
# 9999          NaN         NaN         5         66               NaN
#
#      suspicionlevel lastverdict  countrycode  state   city  hour  day  month  \
# 0        Suspicious  Suspicious          242   1445  10630    22    4      6
# 1        Suspicious  Suspicious          242   1445  10630    12    3      6
# 2        Suspicious  Suspicious          242   1445  10630     3    8      6
# 3               NaN         NaN          242   1445  10630    12   12      6
# 4               NaN         NaN          242   1445  10630    17    6      6
# ...             ...         ...          ...    ...    ...   ...  ...    ...
# 9995            NaN         NaN          242   1445  10630    12    5      6
# 9996            NaN   Malicious          242   1445  10630    20    9      6
# 9997            NaN         NaN           18     91    125     6    3      6
# 9998            NaN         NaN            0     11      8    13   11      6
# 9999            NaN         NaN          242   1445  10630     9   20      5
#
#       year
# 0     2024
# 1     2024
# 2     2024
# 3     2024
# 4     2024
# ...    ...
# 9995  2024
# 9996  2024
# 9997  2024
# 9998  2024
# 9999  2024
#
# [10000 rows x 49 columns]

# %%
df=df.drop(columns=['timestamp','id'])

# %%
# Select the column to move to the last position
column_to_move = 'incidentgrade'

# Move the selected column to the last position
df = df[[col for col in df.columns if col != column_to_move] + [column_to_move]]

# %%
df
# Out:
#       orgid  incidentid  alertid  detectorid  alerttitle           category  \
# 0       657       11767    87199         524         563    LateralMovement
# 1         3       91158   632273           2           2  CommandAndControl
# 2       145       32247   131719        2932       10807    LateralMovement
# 3       222       15294   917686           0           0      InitialAccess
# 4       363        7615     5944          27          18          Discovery
# ...     ...         ...      ...         ...         ...                ...
# 9995     22         933   547212           0           0      InitialAccess
# 9996     36       92513    66367           1           1      InitialAccess
# 9997      5         172   373507           0           0      InitialAccess
# 9998      1         273   402248           0           0      InitialAccess
# 9999      4         398      421           8           7      InitialAccess
#
#                       mitretechniques actiongrouped actiongranular  \
# 0         T1021;T1047;T1105;T1569.002           NaN            NaN
# 1                                 NaN           NaN            NaN
# 2     T1021;T1027.002;T1027.005;T1105           NaN            NaN
# 3                     T1078;T1078.004           NaN            NaN
# 4                     T1087;T1087.002           NaN            NaN
# ...                               ...           ...            ...
# 9995                  T1078;T1078.004           NaN            NaN
# 9996                        T1566.002           NaN            NaN
# 9997                  T1078;T1078.004           NaN            NaN
# 9998                  T1078;T1078.004           NaN            NaN
# 9999                            T1133           NaN            NaN
#
#              entitytype evidencerole  deviceid  sha256  ipaddress     url  \
# 0                  User     Impacted     98799  138268     360606  160396
# 1               Machine     Impacted      1239  138268     360606  160396
# 2               Process      Related     98799    4296     360606  160396
# 3     CloudLogonSession      Related     98799  138268     360606  160396
# 4                  User     Impacted     98799  138268     360606  160396
# ...                 ...          ...       ...     ...        ...     ...
# 9995  CloudLogonRequest      Related     98799  138268     360606  160396
# 9996        MailCluster      Related     98799  138268     360606  160396
# 9997                 Ip      Related     98799  138268      20463  160396
# 9998                 Ip      Related     98799  138268      16281  160396
# 9999            Machine     Impacted     98799  138268     360606  160396
#
#       accountsid  accountupn  accountobjectid  accountname  devicename  \
# 0           2610        3699           425863          863      153085
# 1         441377      673934           425863       453297        2833
# 2         441377      673934           425863       453297      153085
# 3         441377      673934           425863       453297      153085
# 4         133549      673934           425863       136104      153085
# ...          ...         ...              ...          ...         ...
# 9995      441377      673934           425863       453297      153085
# 9996      441377      673934           425863       453297      153085
# 9997      441377      673934           425863       453297      153085
# 9998      441377      673934           425863       453297      153085
# 9999      441377      673934           425863       453297         216
#
#       networkmessageid  emailclusterid  registrykey  registryvaluename  \
# 0               529644             NaN         1631                635
# 1               529644             NaN         1631                635
# 2               529644             NaN         1631                635
# 3               529644             NaN         1631                635
# 4               529644             NaN         1631                635
# ...                ...             ...          ...                ...
# 9995            529644             NaN         1631                635
# 9996            529644             NaN         1631                635
# 9997            529644             NaN         1631                635
# 9998            529644             NaN         1631                635
# 9999            529644             NaN         1631                635
#
#       registryvaluedata  applicationid  applicationname  oauthapplicationid  \
# 0                   860           2251             3421                 881
# 1                   860           2251             3421                 881
# 2                   860           2251             3421                 881
# 3                   860           2251             3421                 881
# 4                   860           2251             3421                 881
# ...                 ...            ...              ...                 ...
# 9995                860           2251             3421                 881
# 9996                860           2251             3421                 881
# 9997                860           2251             3421                 881
# 9998                860           2251             3421                 881
# 9999                860           2251             3421                 881
#
#      threatfamily  filename  folderpath  resourceidname resourcetype  \
# 0             NaN    289573      117668            3586          NaN
# 1             NaN    289573      117668            3586          NaN
# 2             NaN        14          22            3586          NaN
# 3             NaN    289573      117668            3586          NaN
# 4             NaN    289573      117668            3586          NaN
# ...           ...       ...         ...             ...          ...
# 9995          NaN    289573      117668            3586          NaN
# 9996          NaN    289573      117668            3586          NaN
# 9997          NaN    289573      117668            3586          NaN
# 9998          NaN    289573      117668            3586          NaN
# 9999          NaN    289573      117668            3586          NaN
#
#            roles  osfamily  osversion antispamdirection suspicionlevel  \
# 0            NaN         5         66               NaN     Suspicious
# 1            NaN         0          0               NaN     Suspicious
# 2            NaN         5         66               NaN     Suspicious
# 3            NaN         5         66               NaN            NaN
# 4     Suspicious         5         66               NaN            NaN
# ...          ...       ...        ...               ...            ...
# 9995         NaN         5         66               NaN            NaN
# 9996         NaN         5         66               NaN            NaN
# 9997         NaN         5         66               NaN            NaN
# 9998         NaN         5         66               NaN            NaN
# 9999         NaN         5         66               NaN            NaN
#
#      lastverdict  countrycode  state   city  hour  day  month  year  \
# 0     Suspicious          242   1445  10630    22    4      6  2024
# 1     Suspicious          242   1445  10630    12    3      6  2024
# 2     Suspicious          242   1445  10630     3    8      6  2024
# 3            NaN          242   1445  10630    12   12      6  2024
# 4            NaN          242   1445  10630    17    6      6  2024
# ...          ...          ...    ...    ...   ...  ...    ...   ...
# 9995         NaN          242   1445  10630    12    5      6  2024
# 9996   Malicious          242   1445  10630    20    9      6  2024
# 9997         NaN           18     91    125     6    3      6  2024
# 9998         NaN            0     11      8    13   11      6  2024
# 9999         NaN          242   1445  10630     9   20      5  2024
#
#        incidentgrade
# 0     BenignPositive
# 1     BenignPositive
# 2     BenignPositive
# 3      FalsePositive
# 4     BenignPositive
# ...              ...
# 9995    TruePositive
# 9996  BenignPositive
# 9997    TruePositive
# 9998    TruePositive
# 9999   FalsePositive
#
# [10000 rows x 47 columns]

# %%
null_percentage = df.isnull().mean() * 100

# %%
null_percentage
# Out:
# orgid                  0.00
# incidentid             0.00
# alertid                0.00
# detectorid             0.00
# alerttitle             0.00
# category               0.00
# mitretechniques       55.35
# actiongrouped         99.96
# actiongranular        99.96
# entitytype             0.00
# evidencerole           0.00
# deviceid               0.00
# sha256                 0.00
# ipaddress              0.00
# url                    0.00
# accountsid             0.00
# accountupn             0.00
# accountobjectid        0.00
# accountname            0.00
# devicename             0.00
# networkmessageid       0.00
# emailclusterid        99.05
# registrykey            0.00
# registryvaluename      0.00
# registryvaluedata      0.00
# applicationid          0.00
# applicationname        0.00
# oauthapplicationid     0.00
# threatfamily          99.28
# filename               0.00
# folderpath             0.00
# resourceidname         0.00
# resourcetype          99.92
# roles                 97.49
# osfamily               0.00
# osversion              0.00
# antispamdirection     98.01
# suspicionlevel        84.54
# lastverdict           76.09
# countrycode            0.00
# state                  0.00
# city                   0.00
# hour                   0.00
# day                    0.00
# month                  0.00
# year                   0.00
# incidentgrade          0.00
# dtype: float64

# %% [markdown]
# Remove 90% above NULL columns

# %%
# Calculate the threshold for non-null values
threshold = 0.90
non_null_threshold = int((1 - threshold) * len(df))

# Identify columns to be removed
columns_to_remove = df.columns[df.isnull().mean() > threshold]

# Drop columns with more than 90% null values
df_cleaned = df.drop(columns=columns_to_remove)

print("Removed columns:")
print(columns_to_remove.tolist())

print("\nDataFrame after removal:")
print(df_cleaned)
# Out:
# Removed columns:
# ['actiongrouped', 'actiongranular', 'emailclusterid', 'threatfamily', 'resourcetype', 'roles', 'antispamdirection']
#
# DataFrame after removal:
#       orgid  incidentid  alertid  detectorid  alerttitle           category  \
# 0       657       11767    87199         524         563    LateralMovement
# 1         3       91158   632273           2           2  CommandAndControl
# 2       145       32247   131719        2932       10807    LateralMovement
# 3       222       15294   917686           0           0      InitialAccess
# 4       363        7615     5944          27          18          Discovery
# ...     ...         ...      ...         ...         ...                ...
# 9995     22         933   547212           0           0      InitialAccess
# 9996     36       92513    66367           1           1      InitialAccess
# 9997      5         172   373507           0           0      InitialAccess
# 9998      1         273   402248           0           0      InitialAccess
# 9999      4         398      421           8           7      InitialAccess
#
#                       mitretechniques         entitytype evidencerole  \
# 0         T1021;T1047;T1105;T1569.002               User     Impacted
# 1                                 NaN            Machine     Impacted
# 2     T1021;T1027.002;T1027.005;T1105            Process      Related
# 3                     T1078;T1078.004  CloudLogonSession      Related
# 4                     T1087;T1087.002               User     Impacted
# ...                               ...                ...          ...
# 9995                  T1078;T1078.004  CloudLogonRequest      Related
# 9996                        T1566.002        MailCluster      Related
# 9997                  T1078;T1078.004                 Ip      Related
# 9998                  T1078;T1078.004                 Ip      Related
# 9999                            T1133            Machine     Impacted
#
#       deviceid  sha256  ipaddress     url  accountsid  accountupn  \
# 0        98799  138268     360606  160396        2610        3699
# 1         1239  138268     360606  160396      441377      673934
# 2        98799    4296     360606  160396      441377      673934
# 3        98799  138268     360606  160396      441377      673934
# 4        98799  138268     360606  160396      133549      673934
# ...        ...     ...        ...     ...         ...         ...
# 9995     98799  138268     360606  160396      441377      673934
# 9996     98799  138268     360606  160396      441377      673934
# 9997     98799  138268      20463  160396      441377      673934
# 9998     98799  138268      16281  160396      441377      673934
# 9999     98799  138268     360606  160396      441377      673934
#
#       accountobjectid  accountname  devicename  networkmessageid  registrykey  \
# 0              425863          863      153085            529644         1631
# 1              425863       453297        2833            529644         1631
# 2              425863       453297      153085            529644         1631
# 3              425863       453297      153085            529644         1631
# 4              425863       136104      153085            529644         1631
# ...               ...          ...         ...               ...          ...
# 9995           425863       453297      153085            529644         1631
# 9996           425863       453297      153085            529644         1631
# 9997           425863       453297      153085            529644         1631
# 9998           425863       453297      153085            529644         1631
# 9999           425863       453297         216            529644         1631
#
#       registryvaluename  registryvaluedata  applicationid  applicationname  \
# 0                   635                860           2251             3421
# 1                   635                860           2251             3421
# 2                   635                860           2251             3421
# 3                   635                860           2251             3421
# 4                   635                860           2251             3421
# ...                 ...                ...            ...              ...
# 9995                635                860           2251             3421
# 9996                635                860           2251             3421
# 9997                635                860           2251             3421
# 9998                635                860           2251             3421
# 9999                635                860           2251             3421
#
#       oauthapplicationid  filename  folderpath  resourceidname  osfamily  \
# 0                    881    289573      117668            3586         5
# 1                    881    289573      117668            3586         0
# 2                    881        14          22            3586         5
# 3                    881    289573      117668            3586         5
# 4                    881    289573      117668            3586         5
# ...                  ...       ...         ...             ...       ...
# 9995                 881    289573      117668            3586         5
# 9996                 881    289573      117668            3586         5
# 9997                 881    289573      117668            3586         5
# 9998                 881    289573      117668            3586         5
# 9999                 881    289573      117668            3586         5
#
#       osversion suspicionlevel lastverdict  countrycode  state   city  hour  \
# 0            66     Suspicious  Suspicious          242   1445  10630    22
# 1             0     Suspicious  Suspicious          242   1445  10630    12
# 2            66     Suspicious  Suspicious          242   1445  10630     3
# 3            66            NaN         NaN          242   1445  10630    12
# 4            66            NaN         NaN          242   1445  10630    17
# ...         ...            ...         ...          ...    ...    ...   ...
# 9995         66            NaN         NaN          242   1445  10630    12
# 9996         66            NaN   Malicious          242   1445  10630    20
# 9997         66            NaN         NaN           18     91    125     6
# 9998         66            NaN         NaN            0     11      8    13
# 9999         66            NaN         NaN          242   1445  10630     9
#
#       day  month  year   incidentgrade
# 0       4      6  2024  BenignPositive
# 1       3      6  2024  BenignPositive
# 2       8      6  2024  BenignPositive
# 3      12      6  2024   FalsePositive
# 4       6      6  2024  BenignPositive
# ...   ...    ...   ...             ...
# 9995    5      6  2024    TruePositive
# 9996    9      6  2024  BenignPositive
# 9997    3      6  2024    TruePositive
# 9998   11      6  2024    TruePositive
# 9999   20      5  2024   FalsePositive
#
# [10000 rows x 40 columns]

# %%
df['actiongrouped'].value_counts()
# Out:
# actiongrouped
# ContainAccount    3
# IsolateDevice     1
# Name: count, dtype: int64

# %%
df_cleaned
# Out:
#       orgid  incidentid  alertid  detectorid  alerttitle           category  \
# 0       657       11767    87199         524         563    LateralMovement
# 1         3       91158   632273           2           2  CommandAndControl
# 2       145       32247   131719        2932       10807    LateralMovement
# 3       222       15294   917686           0           0      InitialAccess
# 4       363        7615     5944          27          18          Discovery
# ...     ...         ...      ...         ...         ...                ...
# 9995     22         933   547212           0           0      InitialAccess
# 9996     36       92513    66367           1           1      InitialAccess
# 9997      5         172   373507           0           0      InitialAccess
# 9998      1         273   402248           0           0      InitialAccess
# 9999      4         398      421           8           7      InitialAccess
#
#                       mitretechniques         entitytype evidencerole  \
# 0         T1021;T1047;T1105;T1569.002               User     Impacted
# 1                                 NaN            Machine     Impacted
# 2     T1021;T1027.002;T1027.005;T1105            Process      Related
# 3                     T1078;T1078.004  CloudLogonSession      Related
# 4                     T1087;T1087.002               User     Impacted
# ...                               ...                ...          ...
# 9995                  T1078;T1078.004  CloudLogonRequest      Related
# 9996                        T1566.002        MailCluster      Related
# 9997                  T1078;T1078.004                 Ip      Related
# 9998                  T1078;T1078.004                 Ip      Related
# 9999                            T1133            Machine     Impacted
#
#       deviceid  sha256  ipaddress     url  accountsid  accountupn  \
# 0        98799  138268     360606  160396        2610        3699
# 1         1239  138268     360606  160396      441377      673934
# 2        98799    4296     360606  160396      441377      673934
# 3        98799  138268     360606  160396      441377      673934
# 4        98799  138268     360606  160396      133549      673934
# ...        ...     ...        ...     ...         ...         ...
# 9995     98799  138268     360606  160396      441377      673934
# 9996     98799  138268     360606  160396      441377      673934
# 9997     98799  138268      20463  160396      441377      673934
# 9998     98799  138268      16281  160396      441377      673934
# 9999     98799  138268     360606  160396      441377      673934
#
#       accountobjectid  accountname  devicename  networkmessageid  registrykey  \
# 0              425863          863      153085            529644         1631
# 1              425863       453297        2833            529644         1631
# 2              425863       453297      153085            529644         1631
# 3              425863       453297      153085            529644         1631
# 4              425863       136104      153085            529644         1631
# ...               ...          ...         ...               ...          ...
# 9995           425863       453297      153085            529644         1631
# 9996           425863       453297      153085            529644         1631
# 9997           425863       453297      153085            529644         1631
# 9998           425863       453297      153085            529644         1631
# 9999           425863       453297         216            529644         1631
#
#       registryvaluename  registryvaluedata  applicationid  applicationname  \
# 0                   635                860           2251             3421
# 1                   635                860           2251             3421
# 2                   635                860           2251             3421
# 3                   635                860           2251             3421
# 4                   635                860           2251             3421
# ...                 ...                ...            ...              ...
# 9995                635                860           2251             3421
# 9996                635                860           2251             3421
# 9997                635                860           2251             3421
# 9998                635                860           2251             3421
# 9999                635                860           2251             3421
#
#       oauthapplicationid  filename  folderpath  resourceidname  osfamily  \
# 0                    881    289573      117668            3586         5
# 1                    881    289573      117668            3586         0
# 2                    881        14          22            3586         5
# 3                    881    289573      117668            3586         5
# 4                    881    289573      117668            3586         5
# ...                  ...       ...         ...             ...       ...
# 9995                 881    289573      117668            3586         5
# 9996                 881    289573      117668            3586         5
# 9997                 881    289573      117668            3586         5
# 9998                 881    289573      117668            3586         5
# 9999                 881    289573      117668            3586         5
#
#       osversion suspicionlevel lastverdict  countrycode  state   city  hour  \
# 0            66     Suspicious  Suspicious          242   1445  10630    22
# 1             0     Suspicious  Suspicious          242   1445  10630    12
# 2            66     Suspicious  Suspicious          242   1445  10630     3
# 3            66            NaN         NaN          242   1445  10630    12
# 4            66            NaN         NaN          242   1445  10630    17
# ...         ...            ...         ...          ...    ...    ...   ...
# 9995         66            NaN         NaN          242   1445  10630    12
# 9996         66            NaN   Malicious          242   1445  10630    20
# 9997         66            NaN         NaN           18     91    125     6
# 9998         66            NaN         NaN            0     11      8    13
# 9999         66            NaN         NaN          242   1445  10630     9
#
#       day  month  year   incidentgrade
# 0       4      6  2024  BenignPositive
# 1       3      6  2024  BenignPositive
# 2       8      6  2024  BenignPositive
# 3      12      6  2024   FalsePositive
# 4       6      6  2024  BenignPositive
# ...   ...    ...   ...             ...
# 9995    5      6  2024    TruePositive
# 9996    9      6  2024  BenignPositive
# 9997    3      6  2024    TruePositive
# 9998   11      6  2024    TruePositive
# 9999   20      5  2024   FalsePositive
#
# [10000 rows x 40 columns]

# %%
df_cleaned.columns
# Out:
# Index(['orgid', 'incidentid', 'alertid', 'detectorid', 'alerttitle',
#        'category', 'mitretechniques', 'entitytype', 'evidencerole', 'deviceid',
#        'sha256', 'ipaddress', 'url', 'accountsid', 'accountupn',
#        'accountobjectid', 'accountname', 'devicename', 'networkmessageid',
#        'registrykey', 'registryvaluename', 'registryvaluedata',
#        'applicationid', 'applicationname', 'oauthapplicationid', 'filename',
#        'folderpath', 'resourceidname', 'osfamily', 'osversion',
#        'suspicionlevel', 'lastverdict', 'countrycode', 'state', 'city', 'hour',
#        'day', 'month', 'year', 'incidentgrade'],
#       dtype='object')

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 40 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   orgid               10000 non-null  int64
#  1   incidentid          10000 non-null  int64
#  2   alertid             10000 non-null  int64
#  3   detectorid          10000 non-null  int64
#  4   alerttitle          10000 non-null  int64
#  5   category            10000 non-null  object
#  6   mitretechniques     4465 non-null   object
#  7   entitytype          10000 non-null  object
#  8   evidencerole        10000 non-null  object
#  9   deviceid            10000 non-null  int64
#  10  sha256              10000 non-null  int64
#  11  ipaddress           10000 non-null  int64
#  12  url                 10000 non-null  int64
#  13  accountsid          10000 non-null  int64
#  14  accountupn          10000 non-null  int64
#  15  accountobjectid     10000 non-null  int64
#  16  accountname         10000 non-null  int64
#  17  devicename          10000 non-null  int64
#  18  networkmessageid    10000 non-null  int64
#  19  registrykey         10000 non-null  int64
#  20  registryvaluename   10000 non-null  int64
#  21  registryvaluedata   10000 non-null  int64
#  22  applicationid       10000 non-null  int64
#  23  applicationname     10000 non-null  int64
#  24  oauthapplicationid  10000 non-null  int64
#  25  filename            10000 non-null  int64
#  26  folderpath          10000 non-null  int64
#  27  resourceidname      10000 non-null  int64
#  28  osfamily            10000 non-null  int64
#  29  osversion           10000 non-null  int64
#  30  suspicionlevel      1546 non-null   object
#  31  lastverdict         2391 non-null   object
#  32  countrycode         10000 non-null  int64
#  33  state               10000 non-null  int64
#  34  city                10000 non-null  int64
#  35  hour                10000 non-null  int32
#  36  day                 10000 non-null  int32
#  37  month               10000 non-null  int32
#  38  year                10000 non-null  int32
#  39  incidentgrade       10000 non-null  object
# dtypes: int32(4), int64(29), object(7)
# memory usage: 2.9+ MB

# %%
pd.set_option('display.max_columns', None)

# %%
df_cleaned
# Out:
#       orgid  incidentid  alertid  detectorid  alerttitle           category  \
# 0       657       11767    87199         524         563    LateralMovement
# 1         3       91158   632273           2           2  CommandAndControl
# 2       145       32247   131719        2932       10807    LateralMovement
# 3       222       15294   917686           0           0      InitialAccess
# 4       363        7615     5944          27          18          Discovery
# ...     ...         ...      ...         ...         ...                ...
# 9995     22         933   547212           0           0      InitialAccess
# 9996     36       92513    66367           1           1      InitialAccess
# 9997      5         172   373507           0           0      InitialAccess
# 9998      1         273   402248           0           0      InitialAccess
# 9999      4         398      421           8           7      InitialAccess
#
#                       mitretechniques         entitytype evidencerole  \
# 0         T1021;T1047;T1105;T1569.002               User     Impacted
# 1                                 NaN            Machine     Impacted
# 2     T1021;T1027.002;T1027.005;T1105            Process      Related
# 3                     T1078;T1078.004  CloudLogonSession      Related
# 4                     T1087;T1087.002               User     Impacted
# ...                               ...                ...          ...
# 9995                  T1078;T1078.004  CloudLogonRequest      Related
# 9996                        T1566.002        MailCluster      Related
# 9997                  T1078;T1078.004                 Ip      Related
# 9998                  T1078;T1078.004                 Ip      Related
# 9999                            T1133            Machine     Impacted
#
#       deviceid  sha256  ipaddress     url  accountsid  accountupn  \
# 0        98799  138268     360606  160396        2610        3699
# 1         1239  138268     360606  160396      441377      673934
# 2        98799    4296     360606  160396      441377      673934
# 3        98799  138268     360606  160396      441377      673934
# 4        98799  138268     360606  160396      133549      673934
# ...        ...     ...        ...     ...         ...         ...
# 9995     98799  138268     360606  160396      441377      673934
# 9996     98799  138268     360606  160396      441377      673934
# 9997     98799  138268      20463  160396      441377      673934
# 9998     98799  138268      16281  160396      441377      673934
# 9999     98799  138268     360606  160396      441377      673934
#
#       accountobjectid  accountname  devicename  networkmessageid  registrykey  \
# 0              425863          863      153085            529644         1631
# 1              425863       453297        2833            529644         1631
# 2              425863       453297      153085            529644         1631
# 3              425863       453297      153085            529644         1631
# 4              425863       136104      153085            529644         1631
# ...               ...          ...         ...               ...          ...
# 9995           425863       453297      153085            529644         1631
# 9996           425863       453297      153085            529644         1631
# 9997           425863       453297      153085            529644         1631
# 9998           425863       453297      153085            529644         1631
# 9999           425863       453297         216            529644         1631
#
#       registryvaluename  registryvaluedata  applicationid  applicationname  \
# 0                   635                860           2251             3421
# 1                   635                860           2251             3421
# 2                   635                860           2251             3421
# 3                   635                860           2251             3421
# 4                   635                860           2251             3421
# ...                 ...                ...            ...              ...
# 9995                635                860           2251             3421
# 9996                635                860           2251             3421
# 9997                635                860           2251             3421
# 9998                635                860           2251             3421
# 9999                635                860           2251             3421
#
#       oauthapplicationid  filename  folderpath  resourceidname  osfamily  \
# 0                    881    289573      117668            3586         5
# 1                    881    289573      117668            3586         0
# 2                    881        14          22            3586         5
# 3                    881    289573      117668            3586         5
# 4                    881    289573      117668            3586         5
# ...                  ...       ...         ...             ...       ...
# 9995                 881    289573      117668            3586         5
# 9996                 881    289573      117668            3586         5
# 9997                 881    289573      117668            3586         5
# 9998                 881    289573      117668            3586         5
# 9999                 881    289573      117668            3586         5
#
#       osversion suspicionlevel lastverdict  countrycode  state   city  hour  \
# 0            66     Suspicious  Suspicious          242   1445  10630    22
# 1             0     Suspicious  Suspicious          242   1445  10630    12
# 2            66     Suspicious  Suspicious          242   1445  10630     3
# 3            66            NaN         NaN          242   1445  10630    12
# 4            66            NaN         NaN          242   1445  10630    17
# ...         ...            ...         ...          ...    ...    ...   ...
# 9995         66            NaN         NaN          242   1445  10630    12
# 9996         66            NaN   Malicious          242   1445  10630    20
# 9997         66            NaN         NaN           18     91    125     6
# 9998         66            NaN         NaN            0     11      8    13
# 9999         66            NaN         NaN          242   1445  10630     9
#
#       day  month  year   incidentgrade
# 0       4      6  2024  BenignPositive
# 1       3      6  2024  BenignPositive
# 2       8      6  2024  BenignPositive
# 3      12      6  2024   FalsePositive
# 4       6      6  2024  BenignPositive
# ...   ...    ...   ...             ...
# 9995    5      6  2024    TruePositive
# 9996    9      6  2024  BenignPositive
# 9997    3      6  2024    TruePositive
# 9998   11      6  2024    TruePositive
# 9999   20      5  2024   FalsePositive
#
# [10000 rows x 40 columns]

# %%
df_cleaned = df_cleaned.astype("category")

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 40 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   orgid               10000 non-null  category
#  1   incidentid          10000 non-null  category
#  2   alertid             10000 non-null  category
#  3   detectorid          10000 non-null  category
#  4   alerttitle          10000 non-null  category
#  5   category            10000 non-null  category
#  6   mitretechniques     4465 non-null   category
#  7   entitytype          10000 non-null  category
#  8   evidencerole        10000 non-null  category
#  9   deviceid            10000 non-null  category
#  10  sha256              10000 non-null  category
#  11  ipaddress           10000 non-null  category
#  12  url                 10000 non-null  category
#  13  accountsid          10000 non-null  category
#  14  accountupn          10000 non-null  category
#  15  accountobjectid     10000 non-null  category
#  16  accountname         10000 non-null  category
#  17  devicename          10000 non-null  category
#  18  networkmessageid    10000 non-null  category
#  19  registrykey         10000 non-null  category
#  20  registryvaluename   10000 non-null  category
#  21  registryvaluedata   10000 non-null  category
#  22  applicationid       10000 non-null  category
#  23  applicationname     10000 non-null  category
#  24  oauthapplicationid  10000 non-null  category
#  25  filename            10000 non-null  category
#  26  folderpath          10000 non-null  category
#  27  resourceidname      10000 non-null  category
#  28  osfamily            10000 non-null  category
#  29  osversion           10000 non-null  category
#  30  suspicionlevel      1546 non-null   category
#  31  lastverdict         2391 non-null   category
#  32  countrycode         10000 non-null  category
#  33  state               10000 non-null  category
#  34  city                10000 non-null  category
#  35  hour                10000 non-null  category
#  36  day                 10000 non-null  category
#  37  month               10000 non-null  category
#  38  year                10000 non-null  category
#  39  incidentgrade       10000 non-null  category
# dtypes: category(40)
# memory usage: 2.0 MB

# %% [markdown]
# Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
le = LabelEncoder()

# Select the categorical columns
category_columns = df_cleaned.select_dtypes(include=['category']).columns

# Apply the LabelEncoder to each categorical column
for col in category_columns:
    df_cleaned[col] = le.fit_transform(df_cleaned[col])

# %%
df_cleaned
# Out:
#       orgid  incidentid  alertid  detectorid  alerttitle  category  \
# 0       580        1726     2976         395         437        11
# 1         3        4088     6652           2           2         1
# 2       142        2724     3441         718        1311        11
# 3       211        1918     7626           0           0        10
# 4       339        1377     1071          26          18         5
# ...     ...         ...      ...         ...         ...       ...
# 9995     21         250     6239           0           0        10
# 9996     34        4109     2694           1           1        10
# 9997      5          48     5317           0           0        10
# 9998      1          86     5502           0           0        10
# 9999      4         118      145           8           7        10
#
#       mitretechniques  entitytype  evidencerole  deviceid  sha256  ipaddress  \
# 0                  39          20             0       334     537       1825
# 1                 190           8             0        95     537       1825
# 2                  38          15             1       334     276       1825
# 3                  99           4             1       334     537       1825
# 4                 107          20             0       334     537       1825
# ...               ...         ...           ...       ...     ...        ...
# 9995               99           3             1       334     537       1825
# 9996              176           9             1       334     537       1825
# 9997               99           7             1       334     537       1230
# 9998               99           7             1       334     537       1173
# 9999              122           8             0       334     537       1825
#
#       url  accountsid  accountupn  accountobjectid  accountname  devicename  \
# 0     598         454         609             2125          249         767
# 1     598        2156        3278             2125         2241         399
# 2     598        2156        3278             2125         2241         767
# 3     598        2156        3278             2125         2241         767
# 4     598        1717        3278             2125         1807         767
# ...   ...         ...         ...              ...          ...         ...
# 9995  598        2156        3278             2125         2241         767
# 9996  598        2156        3278             2125         2241         767
# 9997  598        2156        3278             2125         2241         767
# 9998  598        2156        3278             2125         2241         767
# 9999  598        2156        3278             2125         2241          95
#
#       networkmessageid  registrykey  registryvaluename  registryvaluedata  \
# 0                 1173            9                  7                  6
# 1                 1173            9                  7                  6
# 2                 1173            9                  7                  6
# 3                 1173            9                  7                  6
# 4                 1173            9                  7                  6
# ...                ...          ...                ...                ...
# 9995              1173            9                  7                  6
# 9996              1173            9                  7                  6
# 9997              1173            9                  7                  6
# 9998              1173            9                  7                  6
# 9999              1173            9                  7                  6
#
#       applicationid  applicationname  oauthapplicationid  filename  \
# 0                16               22                   3       725
# 1                16               22                   3       725
# 2                16               22                   3        14
# 3                16               22                   3       725
# 4                16               22                   3       725
# ...             ...              ...                 ...       ...
# 9995             16               22                   3       725
# 9996             16               22                   3       725
# 9997             16               22                   3       725
# 9998             16               22                   3       725
# 9999             16               22                   3       725
#
#       folderpath  resourceidname  osfamily  osversion  suspicionlevel  \
# 0            446               7         3          7               1
# 1            446               7         0          0               1
# 2             21               7         3          7               1
# 3            446               7         3          7               2
# 4            446               7         3          7               2
# ...          ...             ...       ...        ...             ...
# 9995         446               7         3          7               2
# 9996         446               7         3          7               2
# 9997         446               7         3          7               2
# 9998         446               7         3          7               2
# 9999         446               7         3          7               2
#
#       lastverdict  countrycode  state  city  hour  day  month  year  \
# 0               2           62    154   224    22    3      3     0
# 1               2           62    154   224    12    2      3     0
# 2               2           62    154   224     3    7      3     0
# 3               3           62    154   224    12   11      3     0
# 4               3           62    154   224    17    5      3     0
# ...           ...          ...    ...   ...   ...  ...    ...   ...
# 9995            3           62    154   224    12    4      3     0
# 9996            0           62    154   224    20    8      3     0
# 9997            3           18     82   105     6    2      3     0
# 9998            3            0     11     8    13   10      3     0
# 9999            3           62    154   224     9   19      2     0
#
#       incidentgrade
# 0                 0
# 1                 0
# 2                 0
# 3                 1
# 4                 0
# ...             ...
# 9995              2
# 9996              0
# 9997              2
# 9998              2
# 9999              1
#
# [10000 rows x 40 columns]

# %%
from imblearn.over_sampling import SMOTE
import pandas as pd

# Separate features (X) and target (y)
X = df_cleaned.drop(columns=['incidentgrade'])  # Assuming 'target' is your target column
y = df_cleaned['incidentgrade']

# Initialize SMOTE
smote = SMOTE(random_state=42)

# Apply SMOTE
X_resampled, y_resampled = smote.fit_resample(X, y)

# Create a new DataFrame with the resampled data
df_resampled = pd.concat([X_resampled, y_resampled], axis=1)

# Check the distribution of the resampled target
print("Class distribution after SMOTE:")
print(df_resampled['incidentgrade'].value_counts())
# Out:
# Class distribution after SMOTE:
# incidentgrade
# 0    4192
# 1    4192
# 2    4192
# Name: count, dtype: int64

# %% [markdown]
# Test Train split

# %%
import pandas as pd
from sklearn.model_selection import train_test_split


# Perform train-test split (70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=42)

# Display the shapes of the resulting datasets
print("Training Features Shape:", X_train.shape)
print("Testing Features Shape:", X_test.shape)
print("Training Target Shape:", y_train.shape)
print("Testing Target Shape:", y_test.shape)
# Out:
# Training Features Shape: (8803, 39)
# Testing Features Shape: (3773, 39)
# Training Target Shape: (8803,)
# Testing Target Shape: (3773,)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

model = LogisticRegression(max_iter=1000)  # Increased max_iter to ensure convergence
model.fit(X_train, y_train)

# Step 4: Predict on the test data
y_pred = model.predict(X_test)

# Step 5: Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the evaluation results
print("Accuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)
# Out:
# Accuracy: 0.6069440763318315
#
# Confusion Matrix:
#  [[775 347 153]
#  [372 697 159]
#  [286 166 818]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.54      0.61      0.57      1275
#            1       0.58      0.57      0.57      1228
#            2       0.72      0.64      0.68      1270
#
#     accuracy                           0.61      3773
#    macro avg       0.61      0.61      0.61      3773
# weighted avg       0.61      0.61      0.61      3773
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Doing Hyper parameter Tuning

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

logreg = LogisticRegression(max_iter=1000)

# Step 4: Define the hyperparameter grid for tuning
param_grid = {
    'C': [1, 10, 100],  # Regularization strength
    'solver': ['liblinear', 'saga', 'lbfgs'],  # Optimization algorithms
    'penalty': ['l1', 'l2', 'elasticnet'],  # Regularization type (penalty)
}

# Step 5: Perform Grid Search with cross-validation
grid_search = GridSearchCV(logreg, param_grid, cv=5, verbose=1, n_jobs=-1)
grid_search.fit(X_train, y_train)

# Step 6: Best hyperparameters from Grid Search
print("Best Hyperparameters:", grid_search.best_params_)

# Step 7: Predict on the test set using the best model
y_pred = grid_search.best_estimator_.predict(X_test)

# Step 8: Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the evaluation results
print("\nAccuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 60 fits failed out of a total of 135.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1194, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1194, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py", line 75, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1204, in fit
#     raise ValueError("l1_ratio must be specified when penalty is elasticnet.")
# ValueError: l1_ratio must be specified when penalty is elasticnet.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1194, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [0.61524379 0.6016122         nan 0.61365398 0.6016122  0.60842884
#         nan        nan        nan 0.61513009 0.6016122         nan
#  0.61592561 0.6016122  0.60888345        nan        nan        nan
#  0.61569789 0.6016122         nan 0.61513067 0.6016122  0.6102467
#         nan        nan        nan]
#   warnings.warn(
# Best Hyperparameters: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
#
# Accuracy: 0.6064139941690962
#
# Confusion Matrix:
#  [[754 357 164]
#  [362 700 166]
#  [269 167 834]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.54      0.59      0.57      1275
#            1       0.57      0.57      0.57      1228
#            2       0.72      0.66      0.69      1270
#
#     accuracy                           0.61      3773
#    macro avg       0.61      0.61      0.61      3773
# weighted avg       0.61      0.61      0.61      3773

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


# Step 3: Define and fit the Random Forest model
rf_model = RandomForestClassifier(random_state=42)  # Using default hyperparameters
rf_model.fit(X_train, y_train)

# Step 4: Predict on the test set
y_pred = rf_model.predict(X_test)

# Step 5: Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the evaluation results
print("\nAccuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)
# Out:
# Accuracy: 0.8613835144447389
#
# Confusion Matrix:
#  [[1150   91   34]
#  [ 153 1044   31]
#  [ 154   60 1056]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84      1275
#            1       0.87      0.85      0.86      1228
#            2       0.94      0.83      0.88      1270
#
#     accuracy                           0.86      3773
#    macro avg       0.87      0.86      0.86      3773
# weighted avg       0.87      0.86      0.86      3773

# %% [markdown]
# Hyper parameter Tuning in Random Forest

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from scipy.stats import randint


# Step 3: Define the Random Forest model
rf_model = RandomForestClassifier(random_state=42)

# Step 4: Define the hyperparameter distribution for tuning
param_dist = {
    'n_estimators': randint(10, 200),          # Number of trees in the forest
    'max_features': [ 'sqrt', 'log2'],  # Number of features to consider at each split
    'max_depth': randint(1, 20),                # Maximum depth of the tree
    'min_samples_split': randint(2, 20),        # Minimum number of samples required to split an internal node
    'min_samples_leaf': randint(1, 20),         # Minimum number of samples required to be at a leaf node
}

# Step 5: Perform Randomized Search with cross-validation
random_search = RandomizedSearchCV(rf_model, param_dist, n_iter=100, cv=5, verbose=1, n_jobs=-1, random_state=42)
random_search.fit(X_train, y_train)

# Step 6: Best hyperparameters from Randomized Search
print("Best Hyperparameters:", random_search.best_params_)

# Step 7: Predict on the test set using the best model
y_pred = random_search.best_estimator_.predict(X_test)

# Step 8: Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the evaluation results
print("\nAccuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Best Hyperparameters: {'max_depth': 16, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 133}
#
# Accuracy: 0.8306387490060959
#
# Confusion Matrix:
#  [[1157   95   23]
#  [ 199 1006   23]
#  [ 241   58  971]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.91      0.81      1275
#            1       0.87      0.82      0.84      1228
#            2       0.95      0.76      0.85      1270
#
#     accuracy                           0.83      3773
#    macro avg       0.85      0.83      0.83      3773
# weighted avg       0.85      0.83      0.83      3773

# %% [markdown]
# Gradient Boosting

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report



# Step 3: Define and fit the Gradient Boosting model
gb_model = GradientBoostingClassifier(random_state=42)  # Using default hyperparameters
gb_model.fit(X_train, y_train)

# Step 4: Predict on the test set
y_pred = gb_model.predict(X_test)

# Step 5: Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the evaluation results
print("\nAccuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)
# Out:
# Accuracy: 0.7871720116618076
#
# Confusion Matrix:
#  [[1088  159   28]
#  [ 254  927   47]
#  [ 234   81  955]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.85      0.76      1275
#            1       0.79      0.75      0.77      1228
#            2       0.93      0.75      0.83      1270
#
#     accuracy                           0.79      3773
#    macro avg       0.80      0.79      0.79      3773
# weighted avg       0.80      0.79      0.79      3773

# %% [markdown]
# Hyper parameter Tuning in Gradient Boosting

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report



# Step 2: Define the Gradient Boosting model
gb_model = GradientBoostingClassifier(random_state=42)

# Step 3: Define hyperparameter grid
param_grid = {
    'n_estimators': [50, 100, 200],  # Number of boosting stages to be run
    'learning_rate': [0.01, 0.1, 0.2],  # Step size shrinkage
    'max_depth': [3, 4, 5],  # Maximum depth of the individual estimators
    'subsample': [0.8, 1.0]  # Fraction of samples to be used for fitting the individual base learners
}

# Step 4: Perform Grid Search with cross-validation
grid_search = GridSearchCV(estimator=gb_model, param_grid=param_grid, cv=5, verbose=1, n_jobs=-1)
grid_search.fit(X_train, y_train)

# Step 5: Best hyperparameters from Grid Search
print("Best Hyperparameters:", grid_search.best_params_)

# Step 6: Evaluate the model using the best hyperparameters
best_gb_model = grid_search.best_estimator_
y_pred = best_gb_model.predict(X_test)

# Step 7: Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the evaluation results
print("\nAccuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best Hyperparameters: {'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.8}
#
# Accuracy: 0.8820567187914127
#
# Confusion Matrix:
#  [[1147   83   45]
#  [ 109 1077   42]
#  [ 105   61 1104]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      1275
#            1       0.88      0.88      0.88      1228
#            2       0.93      0.87      0.90      1270
#
#     accuracy                           0.88      3773
#    macro avg       0.88      0.88      0.88      3773
# weighted avg       0.88      0.88      0.88      3773

# %% [markdown]
# Decision Tree

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


# Step 2: Define and fit the Decision Tree model
dt_model = DecisionTreeClassifier(random_state=42)  # Using default hyperparameters
dt_model.fit(X_train, y_train)  # Fit the model on the training data

# Step 3: Predict on the test set
y_pred = dt_model.predict(X_test)

# Step 4: Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the evaluation results
print("\nAccuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)
# Out:
# Accuracy: 0.828518420355155
#
# Confusion Matrix:
#  [[1022  159   94]
#  [ 143 1021   64]
#  [ 104   83 1083]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.80      0.80      1275
#            1       0.81      0.83      0.82      1228
#            2       0.87      0.85      0.86      1270
#
#     accuracy                           0.83      3773
#    macro avg       0.83      0.83      0.83      3773
# weighted avg       0.83      0.83      0.83      3773

# %% [markdown]
# Hyper parameter Tuning in Decision Tree

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Step 2: Define the Decision Tree model
dt_model = DecisionTreeClassifier(random_state=42)  # Using default hyperparameters

# Step 3: Define hyperparameter grid
param_grid = {
    'criterion': ['gini', 'entropy'],  # Measure for splitting
    'max_depth': [ 10, 15, 20],  # Maximum depth of the tree
    'min_samples_split': [2, 5, 10],  # Minimum samples required to split an internal node
    'min_samples_leaf': [1, 2, 4],  # Minimum samples required to be at a leaf node
}

# Step 4: Perform Grid Search with cross-validation
grid_search = GridSearchCV(estimator=dt_model, param_grid=param_grid, cv=5, verbose=1, n_jobs=-1)
grid_search.fit(X_train, y_train)  # Fit the model on the training data

# Step 5: Best hyperparameters from Grid Search
print("Best Hyperparameters:", grid_search.best_params_)

# Step 6: Evaluate the best model on the test set
best_dt_model = grid_search.best_estimator_
y_pred = best_dt_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the evaluation results
print("\nAccuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best Hyperparameters: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Accuracy: 0.8187119003445534
#
# Confusion Matrix:
#  [[1039  169   67]
#  [ 170 1005   53]
#  [ 139   86 1045]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.81      0.79      1275
#            1       0.80      0.82      0.81      1228
#            2       0.90      0.82      0.86      1270
#
#     accuracy                           0.82      3773
#    macro avg       0.82      0.82      0.82      3773
# weighted avg       0.82      0.82      0.82      3773

# %% [markdown]
# Support Vector Machine

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Step 2: Define and fit the Support Vector Machine model
svm_model = SVC(random_state=42)  # Using default hyperparameters
svm_model.fit(X_train, y_train)  # Fit the model on the training data

# Step 3: Predict on the test set
y_pred = svm_model.predict(X_test)

# Step 4: Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the evaluation results
print("\nAccuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)
# Out:
# Accuracy: 0.6334481844685926
#
# Confusion Matrix:
#  [[778 408  89]
#  [298 848  82]
#  [280 226 764]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.57      0.61      0.59      1275
#            1       0.57      0.69      0.63      1228
#            2       0.82      0.60      0.69      1270
#
#     accuracy                           0.63      3773
#    macro avg       0.65      0.63      0.64      3773
# weighted avg       0.66      0.63      0.64      3773

# %% [markdown]
# k-Nearest Neighbors

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Step 2: Define and fit the KNN model
knn_model = KNeighborsClassifier(n_neighbors=5)  # Using 5 neighbors (default)
knn_model.fit(X_train, y_train)  # Fit the model on the training data

# Step 3: Predict on the test set
y_pred = knn_model.predict(X_test)

# Step 4: Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the evaluation results
print("\nAccuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)
# Out:
# Accuracy: 0.7270076861913597
#
# Confusion Matrix:
#  [[877 248 150]
#  [207 966  55]
#  [248 122 900]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.69      0.67      1275
#            1       0.72      0.79      0.75      1228
#            2       0.81      0.71      0.76      1270
#
#     accuracy                           0.73      3773
#    macro avg       0.73      0.73      0.73      3773
# weighted avg       0.73      0.73      0.73      3773

# %% [markdown]
# Naive Bayes

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


# Step 2: Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)  # Fit on training data
X_test = scaler.transform(X_test)        # Transform test data

# Step 3: Initialize the Naive Bayes classifier (GaussianNB)
nb = GaussianNB()

# Step 4: Train the Naive Bayes model
nb.fit(X_train, y_train)

# Step 5: Make predictions on the test set
y_pred = nb.predict(X_test)

# Step 6: Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the evaluation results
print("\nAccuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)
# Out:
# Accuracy: 0.4683275907765704
#
# Confusion Matrix:
#  [[319 900  56]
#  [120 995 113]
#  [122 695 453]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.57      0.25      0.35      1275
#            1       0.38      0.81      0.52      1228
#            2       0.73      0.36      0.48      1270
#
#     accuracy                           0.47      3773
#    macro avg       0.56      0.47      0.45      3773
# weighted avg       0.56      0.47      0.45      3773
